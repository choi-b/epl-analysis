# %%
#Import Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import os
import glob
import datetime
import warnings
warnings.filterwarnings("ignore")

#Modeling
from prophet import Prophet

# %%
df = pd.read_csv('data/EPL_stats_since03.csv')

# %%
df.head()
# Out:
#          Date    HomeTeam       AwayTeam  FTHG  FTAG FTR    HS    AS   HST  \
# 0  2003-08-16     Arsenal        Everton   2.0   1.0   H  11.0  13.0   5.0
# 1  2003-08-16  Birmingham      Tottenham   1.0   0.0   H  10.0  15.0   5.0
# 2  2003-08-16   Blackburn         Wolves   5.0   1.0   H  25.0   8.0  13.0
# 3  2003-08-16      Fulham  Middlesbrough   3.0   2.0   H  17.0   8.0   9.0
# 4  2003-08-16   Leicester    Southampton   2.0   2.0   D  12.0  13.0   7.0
#
#     AST  ...    AF   HC   AC   HY   AY   HR   AR   Referee month_year  \
# 0   7.0  ...  15.0  6.0  9.0  1.0  3.0  1.0  1.0  M Halsey    2003-08
# 1   7.0  ...  27.0  1.0  4.0  3.0  5.0  0.0  0.0  R Styles    2003-08
# 2   5.0  ...  14.0  6.0  2.0  1.0  1.0  0.0  0.0  J Winter    2003-08
# 3   5.0  ...  16.0  7.0  6.0  1.0  1.0  0.0  0.0    G Poll    2003-08
# 4  10.0  ...  15.0  2.0  7.0  3.0  1.0  0.0  0.0   M Riley    2003-08
#
#   WinningTeam
# 0     Arsenal
# 1  Birmingham
# 2   Blackburn
# 3      Fulham
# 4        Draw
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HS', 'AS',
#        'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'Referee',
#        'month_year', 'WinningTeam'],
#       dtype='object')

# %% [markdown]
# ### Analysis 1: Trends for Stats (see how it changed the last 10 or so years, if the game got more physical/offensive/defensive, etc.)
# * See if goals (FTHG/FTAG), number of shots (HST/AST), fouls committed (HF/AF), yellow cards (HY/AY), red cards (HR/AR) changed over time

# %%
df_home_stats = df[['Date','month_year','FTHG', 'HST', 'HF', 'HY', 'HR']] #don't forget to include the date
df_away_stats = df[['Date','month_year','FTAG','AST','AF','AY','AR']]

# %%
df_home_stats.columns = ['Date','month_year','Goals','Shots','Fouls','YellowCards','RedCards']
df_away_stats.columns = ['Date','month_year','Goals','Shots','Fouls','YellowCards','RedCards']

# %%
df_stats = pd.concat([df_home_stats,df_away_stats])
df_stats
# Out:
#             Date month_year  Goals  Shots  Fouls  YellowCards  RedCards
# 0     2003-08-16    2003-08    2.0    5.0    8.0          1.0       1.0
# 1     2003-08-16    2003-08    1.0    5.0   20.0          3.0       0.0
# 2     2003-08-16    2003-08    5.0   13.0    8.0          1.0       0.0
# 3     2003-08-16    2003-08    3.0    9.0   18.0          1.0       0.0
# 4     2003-08-16    2003-08    2.0    7.0   27.0          3.0       0.0
# ...          ...        ...    ...    ...    ...          ...       ...
# 7215  2022-05-22    2022-05    0.0    4.0   22.0          4.0       0.0
# 7216  2022-05-22    2022-05    1.0    2.0    5.0          1.0       0.0
# 7217  2022-05-22    2022-05    1.0    5.0    3.0          0.0       0.0
# 7218  2022-05-22    2022-05    2.0    2.0   11.0          1.0       0.0
# 7219  2022-05-22    2022-05    5.0   13.0    7.0          1.0       0.0
#
# [14440 rows x 7 columns]

# %% [markdown]
# ### Can group by Month/Year BUT prophet can also work with exact dates. Let's give it a try
# * Goals
# * Shots
# * Fouls
# * Yellowcards
# * Redcards

# %%
df_goals_daily = df_stats.groupby('Date')['Goals'].sum().reset_index()
df_goals_daily
# Out:
#             Date  Goals
# 0     2003-08-16   26.0
# 1     2003-08-17   10.0
# 2     2003-08-23   23.0
# 3     2003-08-24    4.0
# 4     2003-08-25    5.0
# ...          ...    ...
# 1984  2022-05-15   22.0
# 1985  2022-05-16    2.0
# 1986  2022-05-17    3.0
# 1987  2022-05-19    9.0
# 1988  2022-05-22   39.0
#
# [1989 rows x 2 columns]

# %%
df_goals_daily.dtypes
# Out:
# Date      object
# Goals    float64
# dtype: object

# %%
#change Date to datetime and rename columns to "ds" and "y"
df_goals_daily['Date'] = pd.to_datetime(df_goals_daily['Date'])
df_goals_daily.columns = ['ds','y']

# %% [markdown]
# #### 1a. Forecasting Number of Goals (daily projection)

# %%
# Python
m = Prophet()
m.fit(df_goals_daily) #if you get an error here, trying running this in a separate conda environment (not BASE)
# Out:
# 19:02:24 - cmdstanpy - INFO - Chain [1] start processing
# 19:02:24 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# Predictions are then made on a dataframe with a column 'ds' containing the dates for which a prediction is to be made.
# * Make a suitable dataframe that extends into the future a specified number of days using the helper method "prophet.make_future_dataframe"

# %%
future = m.make_future_dataframe(periods=365)
future.tail() #predicted into the 2022/2023 season
# Out:
#              ds
# 2349 2023-05-18
# 2350 2023-05-19
# 2351 2023-05-20
# 2352 2023-05-21
# 2353 2023-05-22

# %% [markdown]
# The "predict" method assigns each row in future a predicted value which is the yhat.
#
# The forecast object is a new dataframe that includes the yhat with the forecast, as well as columns for components and uncertainty intervals

# %%
# Python
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 2349 2023-05-18  12.468360    5.293593   19.042662
# 2350 2023-05-19  12.739899    5.396812   19.469800
# 2351 2023-05-20  26.589319   19.665191   33.235890
# 2352 2023-05-21  17.748865   10.683150   24.527952
# 2353 2023-05-22  14.257470    7.353103   21.355428

# %%
# Now, plot the forecast
fig1 = m.plot(forecast)
#A little bit hard to see. We'll try again with the monthly aggregation

# %% [markdown]
# #### Seasonality: use the Prophet.plot_components() method
# * By default, plots the overall trend, and the yearly & weekly seasonalities. (Can also include holidays if you want)

# %%
fig2 = m.plot_components(forecast)

# %% [markdown]
# #### 1b. Forecasting Number of Goals (monthly projection)

# %%
df_goals_monthly = df_stats.groupby('month_year')['Goals'].sum().reset_index()
df_goals_monthly
# Out:
#     month_year  Goals
# 0      2003-08  103.0
# 1      2003-09   87.0
# 2      2003-10   71.0
# 3      2003-11   92.0
# 4      2003-12  131.0
# ..         ...    ...
# 184    2022-01   87.0
# 185    2022-02  105.0
# 186    2022-03   90.0
# 187    2022-04  134.0
# 188    2022-05  137.0
#
# [189 rows x 2 columns]

# %%
#change Date to datetime and rename columns to "ds" and "y"
df_goals_monthly['month_year'] = pd.to_datetime(df_goals_monthly['month_year'])

# %%
#prophet can't work with period dtype...
#df_goals_monthly['month_year'] = df_goals_monthly['month_year'].dt.to_period('M')

# %%
df_goals_monthly.columns = ['ds','y']

# %%
df_goals_monthly
# Out:
#             ds      y
# 0   2003-08-01  103.0
# 1   2003-09-01   87.0
# 2   2003-10-01   71.0
# 3   2003-11-01   92.0
# 4   2003-12-01  131.0
# ..         ...    ...
# 184 2022-01-01   87.0
# 185 2022-02-01  105.0
# 186 2022-03-01   90.0
# 187 2022-04-01  134.0
# 188 2022-05-01  137.0
#
# [189 rows x 2 columns]

# %%
# Python
m = Prophet(weekly_seasonality=True) #try adding the weekly_seasonality=True argument.
m.fit(df_goals_monthly)
# Out:
# 22:32:37 - cmdstanpy - INFO - Chain [1] start processing
# 22:32:37 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=12, freq='M') #can predict future periods by month as well by adding the 'freq' argument
future.tail() #predicted into the 2022/2023 season
# Out:
#             ds
# 196 2022-12-31
# 197 2023-01-31
# 198 2023-02-28
# 199 2023-03-31
# 200 2023-04-30

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds        yhat  yhat_lower  yhat_upper
# 196 2022-12-31  123.864858   98.160153  147.834996
# 197 2023-01-31   93.836960   71.312195  119.085994
# 198 2023-02-28   89.126234   62.404082  114.372367
# 199 2023-03-31  132.504951  106.259510  158.117441
# 200 2023-04-30   89.889328   64.666199  114.617213

# %%
# Now, plot the forecast
fig1 = m.plot(forecast) #makes it a little bit easier to see.

# %%
#Try plotting the forecast components
fig2 = m.plot_components(forecast)

# %% [markdown]
# #### Summary
# * General increasing trends for number of goals the teams are scoring (?)
# * Goals tend to be scored more during weekends, naturally because most games are on weekends (limited number of teams participating in more than 1 competition)
# * One consideration: take into account the offseason. Address the "peak" visible in the summer

# %% [markdown]
# # To see if the patterns are easier to see, look at a single season

# %%
df_goals_last_season = df_goals_monthly[df_goals_monthly['ds']>='2021-08-01'] #2021/2022 seasons, 10 months
df_goals_last_season
# Out:
#             ds      y
# 179 2021-08-01   85.0
# 180 2021-09-01   73.0
# 181 2021-10-01  121.0
# 182 2021-11-01   83.0
# 183 2021-12-01  156.0
# 184 2022-01-01   87.0
# 185 2022-02-01  105.0
# 186 2022-03-01   90.0
# 187 2022-04-01  134.0
# 188 2022-05-01  137.0

# %%
# Python
m = Prophet()
m.fit(df_goals_last_season) #if you get an error here, trying running this in a separate conda environment (not BASE)
# Out:
# 22:32:49 - cmdstanpy - INFO - Chain [1] start processing
# 22:32:49 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=13, freq='M')
future.tail(10) #predicted into the 2022/2023 season
# Out:
#            ds
# 13 2022-08-31
# 14 2022-09-30
# 15 2022-10-31
# 16 2022-11-30
# 17 2022-12-31
# 18 2023-01-31
# 19 2023-02-28
# 20 2023-03-31
# 21 2023-04-30
# 22 2023-05-31

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#            ds        yhat  yhat_lower  yhat_upper
# 18 2023-01-31  166.682912  136.489629  194.884440
# 19 2023-02-28  170.754336  142.720050  200.410127
# 20 2023-03-31  175.261984  144.553044  205.483712
# 21 2023-04-30  179.624224  147.976107  211.097758
# 22 2023-05-31  184.131872  152.757757  215.703378

# %%
# Now, plot the forecast
fig1 = m.plot(forecast) #makes it a little bit easier to see.

# %%
#Try plotting the forecast components
#fig2 = m.plot_components(forecast)
#only includes the trend line due to limited data

# %% [markdown]
# #### Generally speaking, more goals were scored in 2021/2022, as the season went on

# %% [markdown]
# # To work with more points, do the same but include the 2020/2021 season as well
# * looking at last TWO seasons

# %%
df_goals_last_two_seasons = df_goals_monthly[df_goals_monthly['ds']>='2020-08-01'] #2021/2022 seasons, 10 months
df_goals_last_two_seasons
# Out:
#             ds      y
# 170 2020-09-01  103.0
# 171 2020-10-01   97.0
# 172 2020-11-01   90.0
# 173 2020-12-01  144.0
# 174 2021-01-01  120.0
# 175 2021-02-01  131.0
# 176 2021-03-01   74.0
# 177 2021-04-01  113.0
# 178 2021-05-01  152.0
# 179 2021-08-01   85.0
# 180 2021-09-01   73.0
# 181 2021-10-01  121.0
# 182 2021-11-01   83.0
# 183 2021-12-01  156.0
# 184 2022-01-01   87.0
# 185 2022-02-01  105.0
# 186 2022-03-01   90.0
# 187 2022-04-01  134.0
# 188 2022-05-01  137.0

# %%
# Python
m = Prophet()
m.fit(df_goals_last_two_seasons) #if you get an error here, trying running this in a separate conda environment (not BASE)
# Out:
# 22:38:23 - cmdstanpy - INFO - Chain [1] start processing
# 22:38:23 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=13, freq='M')
future.tail(10) #predicted into the 2022/2023 season
# Out:
#            ds
# 22 2022-08-31
# 23 2022-09-30
# 24 2022-10-31
# 25 2022-11-30
# 26 2022-12-31
# 27 2023-01-31
# 28 2023-02-28
# 29 2023-03-31
# 30 2023-04-30
# 31 2023-05-31

# %%
# Now, plot the forecast
fig1 = m.plot(forecast) #makes it a little bit easier to see.

# %%
#fig2 = m.plot_components(forecast) #same as earlier, only shows the trend line
#Not sure why the trend line starts at 2021-08
