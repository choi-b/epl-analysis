# %%
#Import Data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import os
import glob
import datetime
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Data quality is awful, will have to work one file at a time to fix the dates first
# * Combining them and then trying to edit the dates just wouldn't work because there'd be no way to be 100% sure if the month and days flipped unless we look at them season by season
# * Had to inspect the CSV to figure out what was going on (too many columns/blank values, etc.)

# %%
#List all csv files only
csv_files = glob.glob('data/*.{}'.format('csv'))

# %%
#Need to store them in separate dataframe for now
fns = [os.path.splitext(os.path.basename(x))[0] for x in csv_files]

# %%
d = {} #create a dictionary of dataframes
for i in range(len(fns)):
    d[fns[i]] = pd.read_csv(csv_files[i], encoding = 'unicode_escape')

# %%
df_0304 = d['2003-2004']

# %%
df_0304.head()
# Out:
#   Div      Date    HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  16/08/03     Arsenal        Everton     2     1   H     1     0   H
# 1  E0  16/08/03  Birmingham      Tottenham     1     0   H     1     0   H
# 2  E0  16/08/03   Blackburn         Wolves     5     1   H     2     0   H
# 3  E0  16/08/03      Fulham  Middlesbrough     3     2   H     1     1   D
# 4  E0  16/08/03   Leicester    Southampton     2     2   D     2     0   H
#
#    ... B365<2.5  GBAHH  GBAHA  GBAH  LBAHH  LBAHA  LBAH  B365AHH  B365AHA  \
# 0  ...     2.10   1.90   1.90 -1.25   1.90   1.95 -1.25    1.975    1.925
# 1  ...     1.85   2.05   1.75 -0.25   1.75   2.10  0.00    2.100    1.800
# 2  ...     1.90   1.95   1.85 -0.75   2.00   1.85 -0.75    1.950    1.950
# 3  ...     1.70   1.80   2.00  0.00   1.85   2.00  0.00    2.100    1.800
# 4  ...     1.80   1.85   1.95  0.00   1.85   2.00  0.00    1.850    2.050
#
#    B365AH
# 0   -1.25
# 1   -0.25
# 2   -0.75
# 3   -0.25
# 4    0.00
#
# [5 rows x 57 columns]

# %%
df = pd.concat([pd.read_csv(f, on_bad_lines='skip', encoding = 'unicode_escape') for f in csv_files ], ignore_index=True)  #data quality is not very good...
df
# Out:
#        Div        Date        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0       E0    16/08/03         Arsenal        Everton   2.0   1.0   H   1.0
# 1       E0    16/08/03      Birmingham      Tottenham   1.0   0.0   H   1.0
# 2       E0    16/08/03       Blackburn         Wolves   5.0   1.0   H   2.0
# 3       E0    16/08/03          Fulham  Middlesbrough   3.0   2.0   H   1.0
# 4       E0    16/08/03       Leicester    Southampton   2.0   2.0   D   2.0
# ...    ...         ...             ...            ...   ...   ...  ..   ...
# 28516  NaN  05/22/2022  Crystal Palace     Man United   1.0   0.0   H   1.0
# 28517  NaN  05/22/2022       Leicester    Southampton   4.0   1.0   H   0.0
# 28518  NaN  05/22/2022       Liverpool         Wolves   3.0   1.0   H   1.0
# 28519  NaN  05/22/2022        Man City    Aston Villa   3.0   2.0   H   0.0
# 28520  NaN  05/22/2022         Norwich      Tottenham   0.0   5.0   A   0.0
#
#        HTAG HTR  ... AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0       0.0   H  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 1       0.0   H  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 2       0.0   H  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 3       1.0   D  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 4       0.0   H  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# ...     ...  ..  ...  ...       ...       ...    ...    ...      ...      ...
# 28516   0.0   H  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 28517   0.0   D  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 28518   1.0   D  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 28519   1.0   A  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 28520   2.0   A  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
#
#        AvgCAHH  AvgCAHA     WinningTeam
# 0          NaN      NaN             NaN
# 1          NaN      NaN             NaN
# 2          NaN      NaN             NaN
# 3          NaN      NaN             NaN
# 4          NaN      NaN             NaN
# ...        ...      ...             ...
# 28516      NaN      NaN  Crystal Palace
# 28517      NaN      NaN       Leicester
# 28518      NaN      NaN       Liverpool
# 28519      NaN      NaN        Man City
# 28520      NaN      NaN       Tottenham
#
# [28521 rows x 152 columns]

# %%
#check out the data
#df.to_csv('test.csv')

# %%
#way too many columns
df.shape
# Out:
# (28521, 152)

# %%
df['Date'].value_counts() #Also, need to Clean and Reformat Date
# Out:
# 01/01/2020    36
# 02/02/2016    32
# 01/01/2015    30
# 01/01/2014    30
# 01/01/2005    30
#               ..
# 13/12/2010     1
# 02/10/06       1
# 20/12/2010     1
# 27/12/10       1
# 30/04/12       1
# Name: Date, Length: 4969, dtype: int64

# %%
#First focus on the ones that don't have the full year
df['Date'].str.len().value_counts()
# Out:
# 10.0    23670
# 8.0      4850
# Name: Date, dtype: int64

# %%
df.loc[(df['Date'].str.len() == 8)] #More than half the DF
# Out:
#      Div      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0     E0  16/08/03      Arsenal         Everton   2.0   1.0   H   1.0   0.0
# 1     E0  16/08/03   Birmingham       Tottenham   1.0   0.0   H   1.0   0.0
# 2     E0  16/08/03    Blackburn          Wolves   5.0   1.0   H   2.0   0.0
# 3     E0  16/08/03       Fulham   Middlesbrough   3.0   2.0   H   1.0   1.0
# 4     E0  16/08/03    Leicester     Southampton   2.0   2.0   D   2.0   0.0
# ...   ..       ...          ...             ...   ...   ...  ..   ...   ...
# 5226  E0  21/05/17    Liverpool   Middlesbrough   3.0   0.0   H   1.0   0.0
# 5227  E0  21/05/17   Man United  Crystal Palace   2.0   0.0   H   2.0   0.0
# 5228  E0  21/05/17  Southampton           Stoke   0.0   1.0   A   0.0   0.0
# 5229  E0  21/05/17      Swansea       West Brom   2.0   1.0   H   0.0   1.0
# 5230  E0  21/05/17      Watford        Man City   0.0   5.0   A   0.0   4.0
#
#      HTR  ... AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0      H  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 1      H  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 2      H  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 3      D  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 4      H  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# ...   ..  ...  ...       ...       ...    ...    ...      ...      ...
# 5226   H  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 5227   H  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 5228   D  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 5229   A  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 5230   A  ...  NaN       NaN       NaN    NaN    NaN      NaN      NaN
#
#       AvgCAHH  AvgCAHA  WinningTeam
# 0         NaN      NaN          NaN
# 1         NaN      NaN          NaN
# 2         NaN      NaN          NaN
# 3         NaN      NaN          NaN
# 4         NaN      NaN          NaN
# ...       ...      ...          ...
# 5226      NaN      NaN          NaN
# 5227      NaN      NaN          NaN
# 5228      NaN      NaN          NaN
# 5229      NaN      NaN          NaN
# 5230      NaN      NaN          NaN
#
# [4850 rows x 152 columns]

# %% [markdown]
# #### Possible Solution: Split out the Date Column First

# %%
df[['date1', 'date2', 'date3']] = df['Date'].str.split('/', expand=True)

# %%
df.head()
# Out:
#   Div      Date    HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  16/08/03     Arsenal        Everton   2.0   1.0   H   1.0   0.0   H
# 1  E0  16/08/03  Birmingham      Tottenham   1.0   0.0   H   1.0   0.0   H
# 2  E0  16/08/03   Blackburn         Wolves   5.0   1.0   H   2.0   0.0   H
# 3  E0  16/08/03      Fulham  Middlesbrough   3.0   2.0   H   1.0   1.0   D
# 4  E0  16/08/03   Leicester    Southampton   2.0   2.0   D   2.0   0.0   H
#
#    ... PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  WinningTeam  date1  \
# 0  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 1  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 2  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 3  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 4  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
#
#    date2  date3
# 0     08     03
# 1     08     03
# 2     08     03
# 3     08     03
# 4     08     03
#
# [5 rows x 155 columns]

# %%
#For the dates missing the full year, add the '20' in front of it
df.loc[df.date3.str.len()==2, 'date3'] = '20' + df['date3']
#This works because we're only looking at dates from >= 2003

# %%
df.head()
# Out:
#   Div      Date    HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  16/08/03     Arsenal        Everton   2.0   1.0   H   1.0   0.0   H
# 1  E0  16/08/03  Birmingham      Tottenham   1.0   0.0   H   1.0   0.0   H
# 2  E0  16/08/03   Blackburn         Wolves   5.0   1.0   H   2.0   0.0   H
# 3  E0  16/08/03      Fulham  Middlesbrough   3.0   2.0   H   1.0   1.0   D
# 4  E0  16/08/03   Leicester    Southampton   2.0   2.0   D   2.0   0.0   H
#
#    ... PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  WinningTeam  date1  \
# 0  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 1  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 2  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 3  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 4  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
#
#    date2  date3
# 0     08   2003
# 1     08   2003
# 2     08   2003
# 3     08   2003
# 4     08   2003
#
# [5 rows x 155 columns]

# %%
#There was one missing date
df['date2'].isna().sum() #missing
# Out:
# 1

# %%
df[df['date2'].isna()] #but we can safely ignore this row
# Out:
#       Div Date HomeTeam AwayTeam  FTHG  FTAG  FTR  HTHG  HTAG  HTR  ... PCAHH  \
# 4470  NaN  NaN      NaN      NaN   NaN   NaN  NaN   NaN   NaN  NaN  ...   NaN
#
#       PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  WinningTeam  date1  date2  \
# 4470    NaN      NaN      NaN      NaN      NaN          NaN    NaN    NaN
#
#       date3
# 4470    NaN
#
# [1 rows x 155 columns]

# %%
df = df[df['date2'].notna()]

# %% [markdown]
# ### REALLY TRICKY: need to change dd/mm/yyyy (which I think all of Europe uses) to mm/dd/yyyy

# %%
df.head() #For the majority of the dates, they need to be rearranged as "date2" + "date1" + "date3"
# Out:
#   Div      Date    HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  16/08/03     Arsenal        Everton   2.0   1.0   H   1.0   0.0   H
# 1  E0  16/08/03  Birmingham      Tottenham   1.0   0.0   H   1.0   0.0   H
# 2  E0  16/08/03   Blackburn         Wolves   5.0   1.0   H   2.0   0.0   H
# 3  E0  16/08/03      Fulham  Middlesbrough   3.0   2.0   H   1.0   1.0   D
# 4  E0  16/08/03   Leicester    Southampton   2.0   2.0   D   2.0   0.0   H
#
#    ... PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  WinningTeam  date1  \
# 0  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 1  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 2  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 3  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
# 4  ...   NaN    NaN      NaN      NaN      NaN      NaN          NaN     16
#
#    date2  date3
# 0     08   2003
# 1     08   2003
# 2     08   2003
# 3     08   2003
# 4     08   2003
#
# [5 rows x 155 columns]

# %%
#First we can change the rows where date1 > 12 since December is the last month
df[df['date1'].astype(int)>12]
# Out:
#        Div        Date        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0       E0    16/08/03         Arsenal        Everton   2.0   1.0   H   1.0
# 1       E0    16/08/03      Birmingham      Tottenham   1.0   0.0   H   1.0
# 2       E0    16/08/03       Blackburn         Wolves   5.0   1.0   H   2.0
# 3       E0    16/08/03          Fulham  Middlesbrough   3.0   2.0   H   1.0
# 4       E0    16/08/03       Leicester    Southampton   2.0   2.0   D   2.0
# ...    ...         ...             ...            ...   ...   ...  ..   ...
# 21386  NaN  22/05/2022  Crystal Palace     Man United   1.0   0.0   H   1.0
# 21387  NaN  22/05/2022       Leicester    Southampton   4.0   1.0   H   0.0
# 21388  NaN  22/05/2022       Liverpool         Wolves   3.0   1.0   H   1.0
# 21389  NaN  22/05/2022        Man City    Aston Villa   3.0   2.0   H   0.0
# 21390  NaN  22/05/2022         Norwich      Tottenham   0.0   5.0   A   0.0
#
#        HTAG HTR  ... PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0       0.0   H  ...   NaN    NaN      NaN      NaN      NaN      NaN
# 1       0.0   H  ...   NaN    NaN      NaN      NaN      NaN      NaN
# 2       0.0   H  ...   NaN    NaN      NaN      NaN      NaN      NaN
# 3       1.0   D  ...   NaN    NaN      NaN      NaN      NaN      NaN
# 4       0.0   H  ...   NaN    NaN      NaN      NaN      NaN      NaN
# ...     ...  ..  ...   ...    ...      ...      ...      ...      ...
# 21386   0.0   H  ...   NaN    NaN      NaN      NaN      NaN      NaN
# 21387   0.0   D  ...   NaN    NaN      NaN      NaN      NaN      NaN
# 21388   1.0   D  ...   NaN    NaN      NaN      NaN      NaN      NaN
# 21389   1.0   A  ...   NaN    NaN      NaN      NaN      NaN      NaN
# 21390   2.0   A  ...   NaN    NaN      NaN      NaN      NaN      NaN
#
#           WinningTeam  date1  date2  date3
# 0                 NaN     16     08   2003
# 1                 NaN     16     08   2003
# 2                 NaN     16     08   2003
# 3                 NaN     16     08   2003
# 4                 NaN     16     08   2003
# ...               ...    ...    ...    ...
# 21386  Crystal Palace     22     05   2022
# 21387       Leicester     22     05   2022
# 21388       Liverpool     22     05   2022
# 21389        Man City     22     05   2022
# 21390       Tottenham     22     05   2022
#
# [8906 rows x 155 columns]

# %%
mask = df['date1'].astype(int)>12
df.loc[mask, 'Date'] = df[['date2','date1','date3']].apply(lambda row: '/'.join(row.values.astype(str)), axis=1)

# %%
df[df['date1'].astype(int)>12] #looks ok
# Out:
#        Div        Date        HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0       E0  08/16/2003         Arsenal        Everton   2.0   1.0   H   1.0
# 1       E0  08/16/2003      Birmingham      Tottenham   1.0   0.0   H   1.0
# 2       E0  08/16/2003       Blackburn         Wolves   5.0   1.0   H   2.0
# 3       E0  08/16/2003          Fulham  Middlesbrough   3.0   2.0   H   1.0
# 4       E0  08/16/2003       Leicester    Southampton   2.0   2.0   D   2.0
# ...    ...         ...             ...            ...   ...   ...  ..   ...
# 21386  NaN  05/22/2022  Crystal Palace     Man United   1.0   0.0   H   1.0
# 21387  NaN  05/22/2022       Leicester    Southampton   4.0   1.0   H   0.0
# 21388  NaN  05/22/2022       Liverpool         Wolves   3.0   1.0   H   1.0
# 21389  NaN  05/22/2022        Man City    Aston Villa   3.0   2.0   H   0.0
# 21390  NaN  05/22/2022         Norwich      Tottenham   0.0   5.0   A   0.0
#
#        HTAG HTR  ... PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  \
# 0       0.0   H  ...   NaN      NaN      NaN      NaN      NaN
# 1       0.0   H  ...   NaN      NaN      NaN      NaN      NaN
# 2       0.0   H  ...   NaN      NaN      NaN      NaN      NaN
# 3       1.0   D  ...   NaN      NaN      NaN      NaN      NaN
# 4       0.0   H  ...   NaN      NaN      NaN      NaN      NaN
# ...     ...  ..  ...   ...      ...      ...      ...      ...
# 21386   0.0   H  ...   NaN      NaN      NaN      NaN      NaN
# 21387   0.0   D  ...   NaN      NaN      NaN      NaN      NaN
# 21388   1.0   D  ...   NaN      NaN      NaN      NaN      NaN
# 21389   1.0   A  ...   NaN      NaN      NaN      NaN      NaN
# 21390   2.0   A  ...   NaN      NaN      NaN      NaN      NaN
#
#           WinningTeam  date1  date2  date3   Datetime
# 0                 NaN     16     08   2003 2003-08-16
# 1                 NaN     16     08   2003 2003-08-16
# 2                 NaN     16     08   2003 2003-08-16
# 3                 NaN     16     08   2003 2003-08-16
# 4                 NaN     16     08   2003 2003-08-16
# ...               ...    ...    ...    ...        ...
# 21386  Crystal Palace     22     05   2022 2022-05-22
# 21387       Leicester     22     05   2022 2022-05-22
# 21388       Liverpool     22     05   2022 2022-05-22
# 21389        Man City     22     05   2022 2022-05-22
# 21390       Tottenham     22     05   2022 2022-05-22
#
# [8906 rows x 156 columns]

# %%
#Make it into a datetime object just in case
df['Datetime'] = pd.to_datetime(df['Date'])

# %%
#Another quality check
df['Datetime'].max() #doesn't seem right since the season ends in May usually
# Out:
# Timestamp('2022-12-05 00:00:00')

# %%
df['month_year'] = df['Datetime'].dt.to_period('M')

# %%
df[df['month_year']== '2022-10']
# Out:
#        Div        Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 6973    E0  10/02/2022    Liverpool       Leicester   2.0   0.0   H   1.0
# 6974    E0  10/02/2022       Wolves         Arsenal   0.0   1.0   A   0.0
# 7018    E0  10/03/2022      Norwich         Chelsea   1.0   3.0   A   0.0
# 7019    E0  10/03/2022  Southampton       Newcastle   1.0   2.0   A   1.0
# 7020    E0  10/03/2022       Wolves         Watford   4.0   0.0   H   2.0
# 7021    E0  10/03/2022        Leeds     Aston Villa   0.0   3.0   A   0.0
# 7056    E0  10/04/2022    Brentford        West Ham   2.0   0.0   H   0.0
# 7057    E0  10/04/2022    Leicester  Crystal Palace   2.0   1.0   H   2.0
# 7058    E0  10/04/2022      Norwich         Burnley   2.0   0.0   H   1.0
# 7059    E0  10/04/2022     Man City       Liverpool   2.0   2.0   D   2.0
# 7103    E0  10/05/2022  Aston Villa       Liverpool   1.0   2.0   A   1.0
# 21233  NaN  10/02/2022    Liverpool       Leicester   2.0   0.0   H   1.0
# 21234  NaN  10/02/2022       Wolves         Arsenal   0.0   1.0   A   0.0
# 21278  NaN  10/03/2022      Norwich         Chelsea   1.0   3.0   A   0.0
# 21279  NaN  10/03/2022  Southampton       Newcastle   1.0   2.0   A   1.0
# 21280  NaN  10/03/2022       Wolves         Watford   4.0   0.0   H   2.0
# 21281  NaN  10/03/2022        Leeds     Aston Villa   0.0   3.0   A   0.0
# 21316  NaN  10/04/2022    Brentford        West Ham   2.0   0.0   H   0.0
# 21317  NaN  10/04/2022    Leicester  Crystal Palace   2.0   1.0   H   2.0
# 21318  NaN  10/04/2022      Norwich         Burnley   2.0   0.0   H   1.0
# 21319  NaN  10/04/2022     Man City       Liverpool   2.0   2.0   D   2.0
# 21363  NaN  10/05/2022  Aston Villa       Liverpool   1.0   2.0   A   1.0
#
#        HTAG HTR  ... MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA  WinningTeam  date1  \
# 6973    0.0   H  ...    2.10     2.15     1.95     1.94          NaN     10
# 6974    1.0   A  ...    2.27     2.03     2.01     1.88          NaN     10
# 7018    2.0   A  ...    2.10     1.93     2.02     1.87          NaN     10
# 7019    1.0   D  ...    2.06     2.04     1.96     1.91          NaN     10
# 7020    0.0   H  ...    1.98     1.99     1.93     1.95          NaN     10
# 7021    1.0   A  ...    1.87     2.17     1.77     2.12          NaN     10
# 7056    0.0   D  ...    2.05     2.05     1.92     1.96          NaN     10
# 7057    0.0   H  ...    1.86     2.32     1.78     2.11          NaN     10
# 7058    0.0   H  ...    1.88     2.08     1.85     2.03          NaN     10
# 7059    1.0   H  ...    2.07     1.95     1.99     1.89          NaN     10
# 7103    1.0   D  ...    2.14     1.93     2.04     1.85          NaN     10
# 21233   0.0   H  ...     NaN      NaN      NaN      NaN    Liverpool     10
# 21234   1.0   A  ...     NaN      NaN      NaN      NaN      Arsenal     10
# 21278   2.0   A  ...     NaN      NaN      NaN      NaN      Chelsea     10
# 21279   1.0   D  ...     NaN      NaN      NaN      NaN    Newcastle     10
# 21280   0.0   H  ...     NaN      NaN      NaN      NaN       Wolves     10
# 21281   1.0   A  ...     NaN      NaN      NaN      NaN  Aston Villa     10
# 21316   0.0   D  ...     NaN      NaN      NaN      NaN    Brentford     10
# 21317   0.0   H  ...     NaN      NaN      NaN      NaN    Leicester     10
# 21318   0.0   H  ...     NaN      NaN      NaN      NaN      Norwich     10
# 21319   1.0   H  ...     NaN      NaN      NaN      NaN         Draw     10
# 21363   1.0   D  ...     NaN      NaN      NaN      NaN    Liverpool     10
#
#        date2  date3   Datetime  month_year
# 6973      02   2022 2022-10-02     2022-10
# 6974      02   2022 2022-10-02     2022-10
# 7018      03   2022 2022-10-03     2022-10
# 7019      03   2022 2022-10-03     2022-10
# 7020      03   2022 2022-10-03     2022-10
# 7021      03   2022 2022-10-03     2022-10
# 7056      04   2022 2022-10-04     2022-10
# 7057      04   2022 2022-10-04     2022-10
# 7058      04   2022 2022-10-04     2022-10
# 7059      04   2022 2022-10-04     2022-10
# 7103      05   2022 2022-10-05     2022-10
# 21233     02   2022 2022-10-02     2022-10
# 21234     02   2022 2022-10-02     2022-10
# 21278     03   2022 2022-10-03     2022-10
# 21279     03   2022 2022-10-03     2022-10
# 21280     03   2022 2022-10-03     2022-10
# 21281     03   2022 2022-10-03     2022-10
# 21316     04   2022 2022-10-04     2022-10
# 21317     04   2022 2022-10-04     2022-10
# 21318     04   2022 2022-10-04     2022-10
# 21319     04   2022 2022-10-04     2022-10
# 21363     05   2022 2022-10-05     2022-10
#
# [22 rows x 157 columns]

# %%
pd.to_datetime(df['Date']).min()
# Out:
# Timestamp('2003-01-11 00:00:00')

# %%
df.shape
# Out:
# (21390, 155)

# %%
#See how the null values are distributed 
df.isna().sum().sort_values(ascending=False)
#SOA: Sporting Odds Away win Odds.
#LBAHH: Ladbrokes Asian handicap home team odds.. etc
#I personally don't really care about "Winning Odds" data
# Out:
# SOA      21055
# SOD      21055
# SOH      21055
# LBAHH    20749
# LBAHA    20749
#          ...
# HY           0
# AY           0
# HR           0
# AR           0
# date3        0
# Length: 155, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR',
#        ...
#        'PCAHH', 'PCAHA', 'MaxCAHH', 'MaxCAHA', 'AvgCAHH', 'AvgCAHA',
#        'WinningTeam', 'date1', 'date2', 'date3'],
#       dtype='object', length=155)

# %%
#df.to_csv('test.csv')

# %% [markdown]
# ### Select Columns Here! TBH not a lot of useful columns other than the ones below

# %%
#Will Drop some (a LOT of) columns/or keep a few columns
df = df[['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR','HTHG','HTAG','HTR','Referee',
         'HS','AS','HST','AST','HF','AF','HC','AC','HY','AY','HR','AR']]

# %%
df.head()
# Out:
#          Date    HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  08/16/2003     Arsenal        Everton   2.0   1.0   H   1.0   0.0   H
# 1  08/16/2003  Birmingham      Tottenham   1.0   0.0   H   1.0   0.0   H
# 2  08/16/2003   Blackburn         Wolves   5.0   1.0   H   2.0   0.0   H
# 3  08/16/2003      Fulham  Middlesbrough   3.0   2.0   H   1.0   1.0   D
# 4  08/16/2003   Leicester    Southampton   2.0   2.0   D   2.0   0.0   H
#
#     Referee  ...   HST   AST    HF    AF   HC   AC   HY   AY   HR   AR
# 0  M Halsey  ...   5.0   7.0   8.0  15.0  6.0  9.0  1.0  3.0  1.0  1.0
# 1  R Styles  ...   5.0   7.0  20.0  27.0  1.0  4.0  3.0  5.0  0.0  0.0
# 2  J Winter  ...  13.0   5.0   8.0  14.0  6.0  2.0  1.0  1.0  0.0  0.0
# 3    G Poll  ...   9.0   5.0  18.0  16.0  7.0  6.0  1.0  1.0  0.0  0.0
# 4   M Riley  ...   7.0  10.0  27.0  15.0  2.0  7.0  3.0  1.0  0.0  0.0
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG',
#        'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC',
#        'HY', 'AY', 'HR', 'AR'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date         object
# HomeTeam     object
# AwayTeam     object
# FTHG        float64
# FTAG        float64
# FTR          object
# HTHG        float64
# HTAG        float64
# HTR          object
# Referee      object
# HS          float64
# AS          float64
# HST         float64
# AST         float64
# HF          float64
# AF          float64
# HC          float64
# AC          float64
# HY          float64
# AY          float64
# HR          float64
# AR          float64
# dtype: object

# %%
#Change all float columns to int
for c in df.columns:
    if df[c].dtype == float:
        df[c] = df[c].astype(int)

# %%
df.head()
# Out:
#          Date    HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  08/16/2003     Arsenal        Everton     2     1   H     1     0   H
# 1  08/16/2003  Birmingham      Tottenham     1     0   H     1     0   H
# 2  08/16/2003   Blackburn         Wolves     5     1   H     2     0   H
# 3  08/16/2003      Fulham  Middlesbrough     3     2   H     1     1   D
# 4  08/16/2003   Leicester    Southampton     2     2   D     2     0   H
#
#     Referee  ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0  M Halsey  ...    5    7   8  15   6   9   1   3   1   1
# 1  R Styles  ...    5    7  20  27   1   4   3   5   0   0
# 2  J Winter  ...   13    5   8  14   6   2   1   1   0   0
# 3    G Poll  ...    9    5  18  16   7   6   1   1   0   0
# 4   M Riley  ...    7   10  27  15   2   7   3   1   0   0
#
# [5 rows x 22 columns]

# %% [markdown]
# # Analyzing basic football stats: Most Wins, Most Goals Scored, Most Goals Conceeded since '03
#
# * Will need to do some data manipulation

# %%
#1. create a "Winning Team" column
def f(row):
    if row['FTR'] == 'H': #Winning Team is the home team
        val = row['HomeTeam']
    elif row['FTR'] == 'A': #Winning Team is the away team
        val = row['AwayTeam']
    else: #Otherwise, the result is a draw
        val = 'Draw'
    return val

# %%
df['WinningTeam'] = df.apply(f, axis=1)

# %%
df.head()
# Out:
#          Date    HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  08/16/2003     Arsenal        Everton     2     1   H     1     0   H
# 1  08/16/2003  Birmingham      Tottenham     1     0   H     1     0   H
# 2  08/16/2003   Blackburn         Wolves     5     1   H     2     0   H
# 3  08/16/2003      Fulham  Middlesbrough     3     2   H     1     1   D
# 4  08/16/2003   Leicester    Southampton     2     2   D     2     0   H
#
#     Referee  ...  AST  HF  AF  HC  AC  HY  AY  HR  AR  WinningTeam
# 0  M Halsey  ...    7   8  15   6   9   1   3   1   1      Arsenal
# 1  R Styles  ...    7  20  27   1   4   3   5   0   0   Birmingham
# 2  J Winter  ...    5   8  14   6   2   1   1   0   0    Blackburn
# 3    G Poll  ...    5  18  16   7   6   1   1   0   0       Fulham
# 4   M Riley  ...   10  27  15   2   7   3   1   0   0         Draw
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Teams with the Most Wins from 03/04 to end of 21/22 Season

# %%
df['WinningTeam'].value_counts().head(10) #The Big Six Theory is validated?!
# Out:
# Draw          5292
# Chelsea       1299
# Man United    1284
# Man City      1206
# Liverpool     1200
# Arsenal       1179
# Tottenham     1050
# Everton        840
# West Ham       609
# Newcastle      609
# Name: WinningTeam, dtype: int64

# %%
df_wins_since03 = df.groupby(['WinningTeam']).size().sort_values(ascending=False).reset_index(name='Number of Wins')

# %%
#Ignore the draws
#Highlight the Big 6
colors = ['#2ca02c', '#2ca02c', '#2ca02c', '#2ca02c', '#2ca02c','#2ca02c', 
          '#7f7f7f', '#7f7f7f', '#7f7f7f', '#7f7f7f']
ax = df_wins_since03[df_wins_since03['WinningTeam']!='Draw'][:10].plot('WinningTeam','Number of Wins', 
                                                                       kind='bar',
                                                                       color = colors, figsize=(10,10), 
                                                                       label='Number of Wins for the Big 6',
                                                                      fontsize=15)
ax.set_title("Top 10 Teams with Most Wins Since the 03/04 Season", fontsize=20)
ax.set_xlabel("Team", fontsize=15)
ax.set_ylabel("Games Won", fontsize=15)
ax.legend(fontsize=15)

# %% [markdown]
# ## Teams with the Most Goals

# %%
df.head()
# Out:
#          Date    HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  08/16/2003     Arsenal        Everton     2     1   H     1     0   H
# 1  08/16/2003  Birmingham      Tottenham     1     0   H     1     0   H
# 2  08/16/2003   Blackburn         Wolves     5     1   H     2     0   H
# 3  08/16/2003      Fulham  Middlesbrough     3     2   H     1     1   D
# 4  08/16/2003   Leicester    Southampton     2     2   D     2     0   H
#
#     Referee  ...  AST  HF  AF  HC  AC  HY  AY  HR  AR  WinningTeam
# 0  M Halsey  ...    7   8  15   6   9   1   3   1   1      Arsenal
# 1  R Styles  ...    7  20  27   1   4   3   5   0   0   Birmingham
# 2  J Winter  ...    5   8  14   6   2   1   1   0   0    Blackburn
# 3    G Poll  ...    5  18  16   7   6   1   1   0   0       Fulham
# 4   M Riley  ...   10  27  15   2   7   3   1   0   0         Draw
#
# [5 rows x 23 columns]

# %%
#Create a new dataframe pairing team name (column 1) + goals (column 2)
df_home = df[['Date','HomeTeam','FTHG']]
df_home
# Out:
#              Date        HomeTeam  FTHG
# 0      08/16/2003         Arsenal     2
# 1      08/16/2003      Birmingham     1
# 2      08/16/2003       Blackburn     5
# 3      08/16/2003          Fulham     3
# 4      08/16/2003       Leicester     2
# ...           ...             ...   ...
# 21386  05/22/2022  Crystal Palace     1
# 21387  05/22/2022       Leicester     4
# 21388  05/22/2022       Liverpool     3
# 21389  05/22/2022        Man City     3
# 21390  05/22/2022         Norwich     0
#
# [21390 rows x 3 columns]

# %%
#Do the same for away team
df_away = df[['Date','AwayTeam','FTAG']]
df_away
# Out:
#              Date       AwayTeam  FTAG
# 0      08/16/2003        Everton     1
# 1      08/16/2003      Tottenham     0
# 2      08/16/2003         Wolves     1
# 3      08/16/2003  Middlesbrough     2
# 4      08/16/2003    Southampton     2
# ...           ...            ...   ...
# 21386  05/22/2022     Man United     0
# 21387  05/22/2022    Southampton     1
# 21388  05/22/2022         Wolves     1
# 21389  05/22/2022    Aston Villa     2
# 21390  05/22/2022      Tottenham     5
#
# [21390 rows x 3 columns]

# %%
#Match the column names then concatenate the two frames
df_home.columns = ['Date','Team','Goals']
df_away.columns = ['Date','Team','Goals']

# %%
df_goals = pd.concat([df_home,df_away])
df_goals
# Out:
#              Date         Team  Goals
# 0      08/16/2003      Arsenal      2
# 1      08/16/2003   Birmingham      1
# 2      08/16/2003    Blackburn      5
# 3      08/16/2003       Fulham      3
# 4      08/16/2003    Leicester      2
# ...           ...          ...    ...
# 21386  05/22/2022   Man United      0
# 21387  05/22/2022  Southampton      1
# 21388  05/22/2022       Wolves      1
# 21389  05/22/2022  Aston Villa      2
# 21390  05/22/2022    Tottenham      5
#
# [42780 rows x 3 columns]

# %%
df_goals_since03 = df_goals.groupby('Team').sum().sort_values(by='Goals', ascending=False).reset_index() #The Big 6 wins again! 
#"You need to score goals to win football matches"

# %%
#Ignore the draws
colors = ['#2ca02c', '#2ca02c', '#2ca02c', '#2ca02c', '#2ca02c','#2ca02c', 
          '#7f7f7f', '#7f7f7f', '#7f7f7f', '#7f7f7f']
ax = df_goals_since03.head(10).plot("Team","Goals",
                                    kind='bar',
                                    color=colors, 
                                    figsize=(10,10),
                                    label='Number of Goals for the Big 6',
                                    fontsize=15)
ax.set_title("Top 10 Teams with the Most Goals Since the 03/04 Season", fontsize=20)
ax.set_xlabel("Team", fontsize=15)
ax.set_ylabel("Goals Scored", fontsize=15)
ax.legend(fontsize=15)

# %% [markdown]
# ### Random check on Referees

# %%
df['Referee'].value_counts() #Mike Dean refereed the most # of games.
# Out:
# M Dean        1512
# M Atkinson    1377
# A Marriner    1134
# M Oliver       960
# A Taylor       942
#               ...
# A Moss           3
# D Gallaghe       3
# R Martin         3
# St Bennett       3
# O Langford       3
# Name: Referee, Length: 65, dtype: int64

# %%
colors = ['#d62728', '#1f77b4', '#ff7f0e', '#2ca02c', '#9467bd',
          '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']
ax = df['Referee'].value_counts()[:10].plot.bar(color=colors) #Some familiar looking names...
ax.set_title("Top 10 Referees by Number of Games Since '03")
ax.set_xlabel("Referees")
ax.set_ylabel("Number of Games")
# Out:
# Text(0, 0.5, 'Number of Games')

# %% [markdown]
# ### For ease, have a combined dataset stored somewhere

# %%
df.to_csv('data/EPL_stats_since03.csv',index=False)
